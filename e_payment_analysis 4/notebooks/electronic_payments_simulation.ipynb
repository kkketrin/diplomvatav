# %% [markdown]
# # Числена реализация: сравнителен анализ на модели за електронни плащания
#
# Този notebook показва основните стъпки от практическата реализация: генериране на синтетични транзакции, агрегиране на показатели, нормализация, сценарийно класиране, TOPSIS и анализ на чувствителността.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from src.main import run_pipeline

# %% [markdown]
# ## 1. Стартиране на пълния анализ

# %%
results = run_pipeline()
results.keys()

# %% [markdown]
# ## 2. Пример от синтетичните транзакции

# %%
results['transactions'].head()

# %% [markdown]
# ## 3. Агрегирани показатели по платежен модел

# %%
results['aggregated_metrics']

# %% [markdown]
# ## 4. Матрица на решенията

# %%
results['decision_matrix']

# %% [markdown]
# ## 5. Нормализирана матрица

# %%
results['normalized_matrix']

# %% [markdown]
# ## 6. Сценарийно класиране

# %%
results['scenario_scores'].sort_values(['scenario', 'rank'])

# %% [markdown]
# ## 7. Проверка чрез TOPSIS

# %%
results['topsis_balanced']

# %% [markdown]
# ## 8. Анализ на чувствителността

# %%
results['sensitivity_results']

# %% [markdown]
# ## 9. Основни фигури

# %%
from IPython.display import Image, display
figures = [
    'average_cost_by_model.png',
    'average_latency_by_model.png',
    'scenario_scores.png',
    'normalized_matrix_heatmap.png',
    'sensitivity_first_place.png',
]
for figure in figures:
    path = PROJECT_ROOT / 'outputs' / 'figures' / figure
    print(figure)
    display(Image(filename=str(path)))

# %% [markdown]
# ## Кратък извод
#
# Полученото класиране зависи от избраните тегла на критериите. Затова сценарийният подход и анализът на чувствителността са важни за по-обективно сравнение между платежните модели.
